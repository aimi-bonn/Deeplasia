# %%
# %matplotlib inline
from lib.datasets import *
import os
from glob import glob
import matplotlib.pyplot as plt

# %%
dm = RsnaBoneAgeDataModule(
    mask_dir=[
        "../data/masks/rsna_bone_age/tensormask/",
        "../data/masks/rsna_bone_age/tensormask/",
    ]
)

# %%
x = dm.train[0]["x"].numpy()[0,:,:]

# %%
plt.imshow(x)

# %%
plt.show()
